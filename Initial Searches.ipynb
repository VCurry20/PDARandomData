# %% [markdown]
# # Project Initial Review
#
# ***

# %% [markdown]
# 1. First look
# 2. Trying different data sets
# 3. Importing them to look at
#
#
# ****

# %%
import pandas as pd    # import pandas to review data sets

# %% [markdown]
# ### Caffine content
#
# - kaggle dataset of caffine content in different drinks
#
# https://www.kaggle.com/heitornunes/caffeine-content-of-drinks

# %% [markdown]
# ### CSO Dataset
#
# https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/APD05/CSV/1.0/

# %%
df = pd.read_csv("https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/APD05/CSV/1.0/")

# %%
df
# Out:
#     STATISTIC                 Statistic  TLIST(A1)  Year C03430V04137  \
# 0    APD05C01  People with a Disability       2019  2019            A
# 1    APD05C01  People with a Disability       2019  2019            A
# 2    APD05C01  People with a Disability       2019  2019            A
# 3    APD05C01  People with a Disability       2019  2019            A
# 4    APD05C01  People with a Disability       2019  2019            A
# ..        ...                       ...        ...   ...          ...
# 175  APD05C01  People with a Disability       2019  2019           ZZ
# 176  APD05C01  People with a Disability       2019  2019           ZZ
# 177  APD05C01  People with a Disability       2019  2019           ZZ
# 178  APD05C01  People with a Disability       2019  2019           ZZ
# 179  APD05C01  People with a Disability       2019  2019           ZZ
#
#                                NACE Sector C02686V03253  \
# 0    Agriculture, Forestry and Fishing (A)            -
# ...

# %%
df.head()
# Out:
#   STATISTIC                 Statistic  TLIST(A1)  Year C03430V04137  \
# 0  APD05C01  People with a Disability       2019  2019            A
# 1  APD05C01  People with a Disability       2019  2019            A
# 2  APD05C01  People with a Disability       2019  2019            A
# 3  APD05C01  People with a Disability       2019  2019            A
# 4  APD05C01  People with a Disability       2019  2019            A
#
#                              NACE Sector C02686V03253  \
# 0  Agriculture, Forestry and Fishing (A)            -
# 1  Agriculture, Forestry and Fishing (A)           14
# 2  Agriculture, Forestry and Fishing (A)           15
# 3  Agriculture, Forestry and Fishing (A)           16
# 4  Agriculture, Forestry and Fishing (A)           03
#
#                                      Disability Type xlsx.unit  xlsx.value
# 0                                 Total disabilities    Number        1585
# 1           Blindness or a serious vision impairment    Number         110
# ...

# %% [markdown]
# Websites:
#
# > https://libguides.ucd.ie/gisguide/FindSpatialData#s-lib-ctab-14597645-30
#
# > https://libguides.ucd.ie/gisguide/FindSpatialData
#
# > https://www.kaggle.com/datasets

# %% [markdown]
# data set -
#
#
# > https://data.gov.ie/dataset/quarterly-statistical-report-recipients-by-sex?package_type=dataset

# %%
df = pd.read_csv("https://data.gov.ie/dataset/04019ed4-c612-4195-9490-8a276b32f416/resource/9b503827-4aa6-41c9-aacb-80ccea0029a4/download/sex.csv")

# %%
df.head(10)
# Out:
#    period                      programme scheme        scheme_description  \
# 0  2014Q1                       Children     CB             Child Benefit
# 1  2014Q1                       Children    FIS  Family Income Supplement
# 2  2014Q1                       Children     CB             Child Benefit
# 3  2014Q1                       Children    FIS  Family Income Supplement
# 4  2014Q1                       Children     CB             Child Benefit
# 5  2014Q1                       Children    FIS  Family Income Supplement
# 6  2014Q1  Illness,Disability and Caring    CAR          Carers Allowance
# 7  2014Q1  Illness,Disability and Caring   CARB            Carers Benefit
# 8  2014Q1  Illness,Disability and Caring     DB           Illness Benefit
# 9  2014Q1  Illness,Disability and Caring   DPMA      Disability Allowance
#
#                basis  sex_code         sex  recipients
# 0  Social Assistance         0  Both Sexes      623739
# ...

# %% [markdown]
# note:
# If you take the date  - datetime module
#
# programs
#
# sexs - one or the other or both ( limited results to outout
#
# - number -

# %%
age_sex = df[["scheme_description", "sex"]]

# %%
age_sex
# Out:
#                    scheme_description         sex
# 0                       Child Benefit  Both Sexes
# 1            Family Income Supplement  Both Sexes
# 2                       Child Benefit        Male
# 3            Family Income Supplement        Male
# 4                       Child Benefit      Female
# ...                               ...         ...
# 1822                Paternity Benefit      Female
# 1823      Pandemic Unemployment Claim      Female
# 1824             Jobseekers Allowance      Female
# 1825               Jobseekers Benefit      Female
# 1826  Widows Non Contributory Pension      Female
#
# [1827 rows x 2 columns]

# %% [markdown]
# > https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html
#
# > https://towardsdatascience.com/interesting-ways-to-select-pandas-dataframe-columns-b29b82bbfb33

# %% [markdown]
# ![pandastips.PNG](attachment:pandastips.PNG)

# %%
df[df.columns[df.columns.isin(['scheme_description','sex','NON-EXISTANT COLUMN'])]]
# Out:
#                    scheme_description         sex
# 0                       Child Benefit  Both Sexes
# 1            Family Income Supplement  Both Sexes
# 2                       Child Benefit        Male
# 3            Family Income Supplement        Male
# 4                       Child Benefit      Female
# ...                               ...         ...
# 1822                Paternity Benefit      Female
# 1823      Pandemic Unemployment Claim      Female
# 1824             Jobseekers Allowance      Female
# 1825               Jobseekers Benefit      Female
# 1826  Widows Non Contributory Pension      Female
#
# [1827 rows x 2 columns]

# %%
df.filter(regex='e$', axis=1)
# Out:
#                         programme scheme  sex_code
# 0                        Children     CB         0
# 1                        Children    FIS         0
# 2                        Children     CB         1
# 3                        Children    FIS         1
# 4                        Children     CB         2
# ...                           ...    ...       ...
# 1822  Working Age Income Supports    PAT         2
# 1823  Working Age Income Supports    PUP         2
# 1824  Working Age Income Supports     UA         2
# 1825  Working Age Income Supports     UB         2
# 1826  Working Age Income Supports   WNCP         2
#
# [1827 rows x 3 columns]

# %% [markdown]
# note
#
# > https://cmdlinetips.com/2018/02/how-to-subset-pandas-dataframe-based-on-values-of-a-column/
#
# > https://towardsdatascience.com/8-ways-to-filter-pandas-dataframes-d34ba585c1b8

# %% [markdown]
# ****
#
# Potential CSO data frames
#
# ****
#
# > https://data.cso.ie/product/VSBO
#
# > https://data.cso.ie/table/VSA19
#
# > https://data.cso.ie/table/VSA14
#
# > https://data.cso.ie/table/VSA36
#
# ****
#
# Birth Rate Analysis – Global review - Articles  -
#
# > https://data.worldbank.org/indicator/SP.DYN.TFRT.IN?locations=IE
#
# > https://getinthepicture.org/sites/default/files/resources/7.%20Births.pdf
#
# > https://ourworldindata.org/fertility-rate
#
# > https://pubmed.ncbi.nlm.nih.gov/12281339/
#
# > https://paa2015.princeton.edu/papers/150351
#
# > https://bmjopen.bmj.com/content/3/8/e002920
#
# > https://www.macrotrends.net/countries/IRL/ireland/birth-rate
#
# > https://www.rte.ie/brainstorm/2021/0519/1222517-ireland-birth-rates-falling/

# %% [markdown]
# ![alt text](Images/East_Asia_Birthrate.png)

# %% [markdown]
# ***
