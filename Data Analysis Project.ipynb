# %% [markdown]
# # Project - Programming for Data Analysis
#
# Create a Data Set by Simulating a read-world phenomenon of your choosing.
#
# Author: Veronica Curry
#
# Student ID: G00074924
#
# ***

# %% [markdown]
# This project includes the following:
#
# > Choose a real world phenomenon (four variables - minimum 100 data points)
#
# > Investigate variable type, distributions and they relationships with each other
#
# > Synthesise Dataset
#
# > Detail your research - output simulated dataset
#
#
# ***

# %% [markdown]
# ***
#
# I was personally interested in looking for a dataset related to people, or the measurement of a human activity. There are numberous locations for datasets online  - varying from college websites, Government websites and international organisations.
#
# I decided to review Irish Data and therefore decided to review datasets on the CSO website. I felt I would have a clearer background knowledge of the data and it would be of personal interest.
#
# The following are examples of potential datasets that I reviewed for use and an overview of these datasets:

# %%
import pandas as pd

# using Pandas we will view the datasets - importing and reading the CSV files from various locations

# %% [markdown]
# ***
#
# ### Employment and Disability
#
# The following is a dataset of information on the number of people in a given year working in Ireland with a disability, and then from this the different types of disability.
#
#
# > https://data.cso.ie/#
#
# For this dataset you need to go to the CAO site and search the dataset number - APD05
#
# > https://data.cso.ie/table/APD05
#
# [1]

# %%
df = pd.read_csv("https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/APD05/CSV/1.0/")

# [2][3]

# %%
df
# Out:
#     STATISTIC                 Statistic  TLIST(A1)  Year C03430V04137  \
# 0    APD05C01  People with a Disability       2019  2019            A
# 1    APD05C01  People with a Disability       2019  2019            A
# 2    APD05C01  People with a Disability       2019  2019            A
# 3    APD05C01  People with a Disability       2019  2019            A
# 4    APD05C01  People with a Disability       2019  2019            A
# ..        ...                       ...        ...   ...          ...
# 175  APD05C01  People with a Disability       2019  2019           ZZ
# 176  APD05C01  People with a Disability       2019  2019           ZZ
# 177  APD05C01  People with a Disability       2019  2019           ZZ
# 178  APD05C01  People with a Disability       2019  2019           ZZ
# 179  APD05C01  People with a Disability       2019  2019           ZZ
#
#                                NACE Sector C02686V03253  \
# 0    Agriculture, Forestry and Fishing (A)            -
# 1    Agriculture, Forestry and Fishing (A)           14
# 2    Agriculture, Forestry and Fishing (A)           15
# 3    Agriculture, Forestry and Fishing (A)           16
# 4    Agriculture, Forestry and Fishing (A)           03
# ..                                     ...          ...
# 175                                Unknown           08
# 176                                Unknown           04
# 177                                Unknown           05
# 178                                Unknown           06
# 179                                Unknown           09
#
#                                        Disability Type xlsx.unit  xlsx.value
# 0                                   Total disabilities    Number        1585
# 1             Blindness or a serious vision impairment    Number         110
# 2             Deafness or a serious hearing impairment    Number         165
# 3                           An intellectual disability    Number         200
# 4    Difficulty in learning, remembering or concent...    Number         497
# ..                                                 ...       ...         ...
# 175               Psychological or emotional condition    Number        1717
# 176  Difficulty in dressing, bathing or getting aro...    Number        1009
# 177             Difficulty in going outside home alone    Number        1084
# 178  Difficulty in working or attending school/college    Number        2848
# 179    Difficulty in participating in other activities    Number        2744
#
# [180 rows x 10 columns]

# %%
df.head()  # look at the top 5 rows

# [4][5]
# Out:
#   STATISTIC                 Statistic  TLIST(A1)  Year C03430V04137  \
# 0  APD05C01  People with a Disability       2019  2019            A
# 1  APD05C01  People with a Disability       2019  2019            A
# 2  APD05C01  People with a Disability       2019  2019            A
# 3  APD05C01  People with a Disability       2019  2019            A
# 4  APD05C01  People with a Disability       2019  2019            A
#
#                              NACE Sector C02686V03253  \
# 0  Agriculture, Forestry and Fishing (A)            -
# 1  Agriculture, Forestry and Fishing (A)           14
# 2  Agriculture, Forestry and Fishing (A)           15
# 3  Agriculture, Forestry and Fishing (A)           16
# 4  Agriculture, Forestry and Fishing (A)           03
#
#                                      Disability Type xlsx.unit  xlsx.value
# 0                                 Total disabilities    Number        1585
# 1           Blindness or a serious vision impairment    Number         110
# 2           Deafness or a serious hearing impairment    Number         165
# 3                         An intellectual disability    Number         200
# 4  Difficulty in learning, remembering or concent...    Number         497

# %% [markdown]
# While the information on this dataset is illuminating I wanted to look for another dataset with more numbers as opposed to so many text fields.
#
# The CSO provides the included information on the break down of disability in Ireland under various headings.
#
# > https://www.cso.ie/en/releasesandpublications/ep/p-cp9hdc/p8hdc/
#
# > https://www.cso.ie/en/releasesandpublications/ep/p-cp9hdc/p8hdc/p9d/
#
# > https://www.cso.ie/en/releasesandpublications/ep/p-cp9hdc/p8hdc/p9chs/

# %% [markdown]
# ![LabourDis2016.PNG](attachment:LabourDis2016.PNG)

# %% [markdown]
#                                                                                                                      [6]

# %% [markdown]
# ***
#
# ### Crime and Justice
#
# The following is a datasetof Crime rates from 2003 - 2021. They are divided under crime type and also Garda Station.
#
#
# > https://www.cso.ie/en/statistics/crimeandjustice/
#
# > https://data.cso.ie/table/CJQ05
#
#
# note: this data is still under review.
#
# [1][2]

# %%
df = pd.read_csv("https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/CJQ05/CSV/1.0/en")   # read csv

# %%
df
# Out:
#       STATISTIC                                  Statistic  TLIST(Q1) Quarter  \
# 0         CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 1         CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 2         CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 3         CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 4         CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# ...         ...                                        ...        ...     ...
# 21295     CJQ05  Recorded Crime Offences Under Reservation      20213  2021Q3
# 21296     CJQ05  Recorded Crime Offences Under Reservation      20213  2021Q3
# 21297     CJQ05  Recorded Crime Offences Under Reservation      20213  2021Q3
# 21298     CJQ05  Recorded Crime Offences Under Reservation      20213  2021Q3
# 21299     CJQ05  Recorded Crime Offences Under Reservation      20213  2021Q3
#
#        C02479V04377                   Garda Region  C02480V03003  \
# 0                10  10 Dublin Metropolitan Region             1
# 1                10  10 Dublin Metropolitan Region           111
# 2                10  10 Dublin Metropolitan Region           112
# 3                10  10 Dublin Metropolitan Region           113
# 4                10  10 Dublin Metropolitan Region            12
# ...             ...                            ...           ...
# 21295            40             40 Southern Region            15
# 21296            40             40 Southern Region           151
# 21297            40             40 Southern Region           152
# 21298            40             40 Southern Region           153
# 21299            40             40 Southern Region           157
#
#                                          Type of Offence    UNIT  VALUE
# 0                                      Homicide offences  Number      7
# 1                                                 Murder  Number      4
# 2                                           Manslaughter  Number      2
# 3                                            Infanticide  Number      0
# 4                     Dangerous driving leading to death  Number      1
# ...                                                  ...     ...    ...
# 21295  Offences against government, justice procedure...  Number    494
# 21296         Offences against government and its agents  Number     14
# 21297  Organisation of crime and conspiracy to commit...  Number      4
# 21298                   Perverting the course of justice  Number     15
# 21299  Offences while in custody, breach of court orders  Number    461
#
# [21300 rows x 10 columns]

# %%
df.head()          # look at the top 5 rows
# Out:
#   STATISTIC                                  Statistic  TLIST(Q1) Quarter  \
# 0     CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 1     CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 2     CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 3     CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
# 4     CJQ05  Recorded Crime Offences Under Reservation      20031  2003Q1
#
#    C02479V04377                   Garda Region  C02480V03003  \
# 0            10  10 Dublin Metropolitan Region             1
# 1            10  10 Dublin Metropolitan Region           111
# 2            10  10 Dublin Metropolitan Region           112
# 3            10  10 Dublin Metropolitan Region           113
# 4            10  10 Dublin Metropolitan Region            12
#
#                       Type of Offence    UNIT  VALUE
# 0                   Homicide offences  Number      7
# 1                              Murder  Number      4
# 2                        Manslaughter  Number      2
# 3                         Infanticide  Number      0
# 4  Dangerous driving leading to death  Number      1

# %%
df.describe()        # describe the dataframe
# Out:
#           TLIST(Q1)  C02479V04377  C02480V03003         VALUE
# count  21300.000000  21300.000000  21300.000000  21300.000000
# mean   20121.280000     25.000000    351.408451    416.425211
# std       54.113637     11.180602    371.090706    918.125508
# min    20031.000000     10.000000      1.000000      0.000000
# 25%    20073.000000     17.500000     33.000000      4.000000
# 50%    20122.000000     25.000000    151.000000     29.000000
# 75%    20171.000000     32.500000    612.000000    368.000000
# max    20213.000000     40.000000   1221.000000  10467.000000

# %%
df['Quarter'].str.split('Q',expand=True,)    # split the data out in the Quarter column [3][4][5]
# Out:
#           0  1
# 0      2003  1
# 1      2003  1
# 2      2003  1
# 3      2003  1
# 4      2003  1
# ...     ... ..
# 21295  2021  3
# 21296  2021  3
# 21297  2021  3
# 21298  2021  3
# 21299  2021  3
#
# [21300 rows x 2 columns]

# %%
df[['Year', 'Quarter']] = df['Quarter'].str.split('Q',expand=True,)   # add the split data to the data frame [6]

# %%
df
# Out:
#       STATISTIC                                  Statistic  TLIST(Q1) Quarter  \
# 0         CJQ05  Recorded Crime Offences Under Reservation      20031       1
# 1         CJQ05  Recorded Crime Offences Under Reservation      20031       1
# 2         CJQ05  Recorded Crime Offences Under Reservation      20031       1
# 3         CJQ05  Recorded Crime Offences Under Reservation      20031       1
# 4         CJQ05  Recorded Crime Offences Under Reservation      20031       1
# ...         ...                                        ...        ...     ...
# 21295     CJQ05  Recorded Crime Offences Under Reservation      20213       3
# 21296     CJQ05  Recorded Crime Offences Under Reservation      20213       3
# 21297     CJQ05  Recorded Crime Offences Under Reservation      20213       3
# 21298     CJQ05  Recorded Crime Offences Under Reservation      20213       3
# 21299     CJQ05  Recorded Crime Offences Under Reservation      20213       3
#
#        C02479V04377                   Garda Region  C02480V03003  \
# 0                10  10 Dublin Metropolitan Region             1
# 1                10  10 Dublin Metropolitan Region           111
# 2                10  10 Dublin Metropolitan Region           112
# 3                10  10 Dublin Metropolitan Region           113
# 4                10  10 Dublin Metropolitan Region            12
# ...             ...                            ...           ...
# 21295            40             40 Southern Region            15
# 21296            40             40 Southern Region           151
# 21297            40             40 Southern Region           152
# 21298            40             40 Southern Region           153
# 21299            40             40 Southern Region           157
#
#                                          Type of Offence    UNIT  VALUE  Year
# 0                                      Homicide offences  Number      7  2003
# 1                                                 Murder  Number      4  2003
# 2                                           Manslaughter  Number      2  2003
# 3                                            Infanticide  Number      0  2003
# 4                     Dangerous driving leading to death  Number      1  2003
# ...                                                  ...     ...    ...   ...
# 21295  Offences against government, justice procedure...  Number    494  2021
# 21296         Offences against government and its agents  Number     14  2021
# 21297  Organisation of crime and conspiracy to commit...  Number      4  2021
# 21298                   Perverting the course of justice  Number     15  2021
# 21299  Offences while in custody, breach of court orders  Number    461  2021
#
# [21300 rows x 11 columns]

# %%
df['VALUE'].value_counts()                     # Value Column - value counts of each value in this column
# Out:
# 0       2347
# 1       1271
# 2        849
# 3        719
# 4        535
#         ...
# 1977       1
# 1961       1
# 2594       1
# 1881       1
# 2015       1
# Name: VALUE, Length: 2760, dtype: int64

# %%
df.groupby(by=['Year'])['VALUE'].mean()       # group by Year & Value - mean of this group
# Out:
# Year
# 2003    402.069542
# 2004    409.059859
# 2005    444.971831
# 2006    470.818662
# 2007    496.433099
# 2008    518.781690
# 2009    497.176937
# 2010    475.289613
# 2011    448.448944
# 2012    425.553697
# 2013    398.290493
# 2014    392.980634
# 2015    391.057218
# 2016    346.148768
# 2017    371.583627
# 2018    373.699824
# 2019    389.834507
# 2020    324.860035
# 2021    307.884977
# Name: VALUE, dtype: float64

# %%
df.groupby(by=['Year'])['VALUE'].count()     # group by Year & Value - count of inputs ( offences)
# Out:
# Year
# 2003    1136
# 2004    1136
# 2005    1136
# 2006    1136
# 2007    1136
# 2008    1136
# 2009    1136
# 2010    1136
# 2011    1136
# 2012    1136
# 2013    1136
# 2014    1136
# 2015    1136
# 2016    1136
# 2017    1136
# 2018    1136
# 2019    1136
# 2020    1136
# 2021     852
# Name: VALUE, dtype: int64

# %%
df.groupby(by=['Year'])['VALUE'].sum()      # group by Year & Value - sums of total offences
# Out:
# Year
# 2003    456751
# 2004    464692
# 2005    505488
# 2006    534850
# 2007    563948
# 2008    589336
# 2009    564793
# 2010    539929
# 2011    509438
# 2012    483429
# 2013    452458
# 2014    446426
# 2015    444241
# 2016    393225
# 2017    422119
# 2018    424523
# 2019    442852
# 2020    369041
# 2021    262318
# Name: VALUE, dtype: int64

# %%
df.groupby(by=['Year'])['VALUE'].max()     # group by Year & Value - max offences for each year
# Out:
# Year
# 2003     9768
# 2004     9596
# 2005     9003
# 2006     8390
# 2007     8840
# 2008     9100
# 2009     8928
# 2010     9484
# 2011     9385
# 2012     9946
# 2013    10467
# 2014    10334
# 2015    10040
# 2016     8880
# 2017     9450
# 2018     9570
# 2019     9683
# 2020     7966
# 2021     6788
# Name: VALUE, dtype: int64

# %%
df.groupby(by=['Year', 'Type of Offence'])['VALUE'].max()      # year and type of offence
# Out:
# Year  Type of Offence
# 2003  Abandoning a child, child neglect and cruelty     21
#       Abduction of person under 16 years of age          4
#       Aggravated burglary                               64
#       Arson                                            121
#       Assault causing harm, poisoning                  408
#                                                       ...
# 2021  Theft/taking of vehicle and related offences     583
#       Threat to kill or cause serious harm             161
#       Trespass offences                                304
#       Unseaworthy/dangerous use of boat or ship          1
#       Weapons and Explosives Offences                  285
# Name: VALUE, Length: 1349, dtype: int64

# %%
df['TLIST(Q1)'][df['VALUE']].sum()                            # total number of offences

# [7]
# Out:
# 426712397

# %%
df.groupby(['Year', 'Type of Offence'])['VALUE'].count()             # number of reported offences by year - type of offence
# Out:
# Year  Type of Offence
# 2003  Abandoning a child, child neglect and cruelty    16
#       Abduction of person under 16 years of age        16
#       Aggravated burglary                              16
#       Arson                                            16
#       Assault causing harm, poisoning                  16
#                                                        ..
# 2021  Theft/taking of vehicle and related offences     12
#       Threat to kill or cause serious harm             12
#       Trespass offences                                12
#       Unseaworthy/dangerous use of boat or ship        12
#       Weapons and Explosives Offences                  12
# Name: VALUE, Length: 1349, dtype: int64

# %%
df.groupby(['Year', 'Type of Offence','Garda Region'])['VALUE'].sum()  # sum of each offence by location
# Out:
# Year  Type of Offence                                Garda Region
# 2003  Abandoning a child, child neglect and cruelty  10 Dublin Metropolitan Region     51
#                                                      20 North Western Region           42
#                                                      30 Eastern Region                 46
#                                                      40 Southern Region                39
#       Abduction of person under 16 years of age      10 Dublin Metropolitan Region      6
#                                                                                      ...
# 2021  Unseaworthy/dangerous use of boat or ship      40 Southern Region                 1
#       Weapons and Explosives Offences                10 Dublin Metropolitan Region    836
#                                                      20 North Western Region          294
#                                                      30 Eastern Region                333
#                                                      40 Southern Region               376
# Name: VALUE, Length: 5396, dtype: int64

# %%
grouped = df.groupby('Garda Region').agg({'VALUE': [max]})            # group by max offences - total by region

grouped
# Out:
#                                VALUE
#                                  max
# Garda Region
# 10 Dublin Metropolitan Region  10467
# 20 North Western Region         3315
# 30 Eastern Region               4583
# 40 Southern Region              4560

# %%
grouped = df.groupby('Type of Offence').agg({'VALUE': [min, max]})   # min and max number of offences - by type of offence

grouped

# [8]
# Out:
#                                               VALUE
#                                                 min   max
# Type of Offence
# Abandoning a child, child neglect and cruelty     2    61
# Abduction of person under 16 years of age         0     7
# Aggravated burglary                               2    64
# Arson                                            45   249
# Assault causing harm, poisoning                 136   499
# ...                                             ...   ...
# Theft/taking of vehicle and related offences     69  2265
# Threat to kill or cause serious harm              0   164
# Trespass offences                                29   553
# Unseaworthy/dangerous use of boat or ship         0     5
# Weapons and Explosives Offences                  49   510
#
# [71 rows x 2 columns]

# %%
# offences by year

choice_year = ['2020']                          # choose year

rslt_df = df[df['Year'].isin(choice_year)]      # group by year and choice of year

rslt_df                                         # print output

#[9]
# Out:
#       STATISTIC                                  Statistic  TLIST(Q1) Quarter  \
# 19312     CJQ05  Recorded Crime Offences Under Reservation      20201       1
# 19313     CJQ05  Recorded Crime Offences Under Reservation      20201       1
# 19314     CJQ05  Recorded Crime Offences Under Reservation      20201       1
# 19315     CJQ05  Recorded Crime Offences Under Reservation      20201       1
# 19316     CJQ05  Recorded Crime Offences Under Reservation      20201       1
# ...         ...                                        ...        ...     ...
# 20443     CJQ05  Recorded Crime Offences Under Reservation      20204       4
# 20444     CJQ05  Recorded Crime Offences Under Reservation      20204       4
# 20445     CJQ05  Recorded Crime Offences Under Reservation      20204       4
# 20446     CJQ05  Recorded Crime Offences Under Reservation      20204       4
# 20447     CJQ05  Recorded Crime Offences Under Reservation      20204       4
#
#        C02479V04377                   Garda Region  C02480V03003  \
# 19312            10  10 Dublin Metropolitan Region             1
# 19313            10  10 Dublin Metropolitan Region           111
# 19314            10  10 Dublin Metropolitan Region           112
# 19315            10  10 Dublin Metropolitan Region           113
# 19316            10  10 Dublin Metropolitan Region            12
# ...             ...                            ...           ...
# 20443            40             40 Southern Region            15
# 20444            40             40 Southern Region           151
# 20445            40             40 Southern Region           152
# 20446            40             40 Southern Region           153
# 20447            40             40 Southern Region           157
#
#                                          Type of Offence    UNIT  VALUE  Year
# 19312                                  Homicide offences  Number      8  2020
# 19313                                             Murder  Number      5  2020
# 19314                                       Manslaughter  Number      1  2020
# 19315                                        Infanticide  Number      0  2020
# 19316                 Dangerous driving leading to death  Number      2  2020
# ...                                                  ...     ...    ...   ...
# 20443  Offences against government, justice procedure...  Number    639  2020
# 20444         Offences against government and its agents  Number     14  2020
# 20445  Organisation of crime and conspiracy to commit...  Number      1  2020
# 20446                   Perverting the course of justice  Number      1  2020
# 20447  Offences while in custody, breach of court orders  Number    623  2020
#
# [1136 rows x 11 columns]

# %% [markdown]
# The CSO provides the following information on the breakdown of crimes in Ireland:
#
# > https://www.cso.ie/en/releasesandpublications/ep/p-rc/recordedcrimeq32021/
#
# > https://www.cso.ie/en/releasesandpublications/ep/p-rc/recordedcrimeq22021/
#
# [10]

# %% [markdown]
# ![CrimeOffences.PNG](attachment:CrimeOffences.PNG)

# %% [markdown]
# <br>
#
# ***
#
# ### Births
#
# This dataset includes the number of births between 1980 - 2019. There is information on the year, month, rank (month that year with most births)
#
#
# > https://data.cso.ie/table/VSA19
#
#
# [1]

# %%
df = pd.read_csv("https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/VSA19/CSV/1.0/en")

# %%
df
# Out:
#       STATISTIC Statistic  TLIST(A1)  Year C02199V02655 Sex of Child  \
# 0      VSA19C01    Births       1980  1980            -   Both sexes
# 1      VSA19C01    Births       1980  1980            -   Both sexes
# 2      VSA19C01    Births       1980  1980            -   Both sexes
# 3      VSA19C01    Births       1980  1980            -   Both sexes
# 4      VSA19C01    Births       1980  1980            -   Both sexes
# ...         ...       ...        ...   ...          ...          ...
# 92155  VSA19C02      Rank       2019  2019            2       Female
# 92156  VSA19C02      Rank       2019  2019            2       Female
# 92157  VSA19C02      Rank       2019  2019            2       Female
# 92158  VSA19C02      Rank       2019  2019            2       Female
# 92159  VSA19C02      Rank       2019  2019            2       Female
#
#       C01886V02319 Date of Occurrence  C01885V02316 Month of Occurrence  \
# 0                -              Total             1             January
# 1                -              Total             2            February
# 2                -              Total             3               March
# 3                -              Total             4               April
# 4                -              Total             5                 May
# ...            ...                ...           ...                 ...
# 92155           31               31st             8              August
# 92156           31               31st             9           September
# 92157           31               31st            10             October
# 92158           31               31st            11            November
# 92159           31               31st            12            December
#
#          UNIT   VALUE
# 0      Number  6233.0
# 1      Number  5880.0
# 2      Number  6531.0
# 3      Number  6430.0
# 4      Number  6672.0
# ...       ...     ...
# 92155  Number   267.0
# 92156  Number     NaN
# 92157  Number   106.0
# 92158  Number     NaN
# 92159  Number    32.0
#
# [92160 rows x 12 columns]

# %%
df.info()

#[2]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92160 entries, 0 to 92159
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   STATISTIC            92160 non-null  object
#  1   Statistic            92160 non-null  object
#  2   TLIST(A1)            92160 non-null  int64
#  3   Year                 92160 non-null  int64
#  4   C02199V02655         92160 non-null  object
#  5   Sex of Child         92160 non-null  object
#  6   C01886V02319         92160 non-null  object
#  7   Date of Occurrence   92160 non-null  object
#  8   C01885V02316         92160 non-null  int64
#  9   Month of Occurrence  92160 non-null  object
#  10  UNIT                 92160 non-null  object
#  11  VALUE                88740 non-null  float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 8.4+ MB

# %% [markdown]
# <br>
#
# In this dataset we have the following values:
#
# Births or Rank -
#  - Births being the total number of births for that date / Month / Year
#  - Rank - where the total number of births for a date - and place in a total list for the year
#
# Sex of Child -
#  - Male
#  - Female
#  - Both Sexes
#
# Value -
#  - number of births
#
# Date -
#  - Broken into Year / Month / Date
#
# <br>
# Within these columns there is totals - for example the total number of both sexes born on a particular date

# %% [markdown]
# ***
#
# Here we will clean the data to create a working dataframe
#
# ***

# %%
births = df[['Statistic', 'Year','Sex of Child', 'C01886V02319', 'Date of Occurrence','Month of Occurrence', 'VALUE']]

# %%
births

#[3]
# Out:
#       Statistic  Year Sex of Child C01886V02319 Date of Occurrence  \
# 0        Births  1980   Both sexes            -              Total
# 1        Births  1980   Both sexes            -              Total
# 2        Births  1980   Both sexes            -              Total
# 3        Births  1980   Both sexes            -              Total
# 4        Births  1980   Both sexes            -              Total
# ...         ...   ...          ...          ...                ...
# 92155      Rank  2019       Female           31               31st
# 92156      Rank  2019       Female           31               31st
# 92157      Rank  2019       Female           31               31st
# 92158      Rank  2019       Female           31               31st
# 92159      Rank  2019       Female           31               31st
#
#       Month of Occurrence   VALUE
# 0                 January  6233.0
# 1                February  5880.0
# 2                   March  6531.0
# 3                   April  6430.0
# 4                     May  6672.0
# ...                   ...     ...
# 92155              August   267.0
# 92156           September     NaN
# 92157             October   106.0
# 92158            November     NaN
# 92159            December    32.0
#
# [92160 rows x 7 columns]

# %%
# reorder these columns

births = df[['Statistic', 'C01886V02319', 'Date of Occurrence', 'Month of Occurrence', 'Year', 'Sex of Child','VALUE' ]]

# %%
births
# Out:
#       Statistic C01886V02319 Date of Occurrence Month of Occurrence  Year  \
# 0        Births            -              Total             January  1980
# 1        Births            -              Total            February  1980
# 2        Births            -              Total               March  1980
# 3        Births            -              Total               April  1980
# 4        Births            -              Total                 May  1980
# ...         ...          ...                ...                 ...   ...
# 92155      Rank           31               31st              August  2019
# 92156      Rank           31               31st           September  2019
# 92157      Rank           31               31st             October  2019
# 92158      Rank           31               31st            November  2019
# 92159      Rank           31               31st            December  2019
#
#       Sex of Child   VALUE
# 0       Both sexes  6233.0
# 1       Both sexes  5880.0
# 2       Both sexes  6531.0
# 3       Both sexes  6430.0
# 4       Both sexes  6672.0
# ...            ...     ...
# 92155       Female   267.0
# 92156       Female     NaN
# 92157       Female   106.0
# 92158       Female     NaN
# 92159       Female    32.0
#
# [92160 rows x 7 columns]

# %%
# births.columns = ['Statistic', 'Year','Sex', 'Rank', 'Day of Occurrence', 'Month of Occurrence', 'Births']

births.columns = ['Statistic', 'Rank','Date', 'Month', 'Year', 'Sex', 'Births']

# %%
births

#[4]
# Out:
#       Statistic Rank   Date      Month  Year         Sex  Births
# 0        Births    -  Total    January  1980  Both sexes  6233.0
# 1        Births    -  Total   February  1980  Both sexes  5880.0
# 2        Births    -  Total      March  1980  Both sexes  6531.0
# 3        Births    -  Total      April  1980  Both sexes  6430.0
# 4        Births    -  Total        May  1980  Both sexes  6672.0
# ...         ...  ...    ...        ...   ...         ...     ...
# 92155      Rank   31   31st     August  2019      Female   267.0
# 92156      Rank   31   31st  September  2019      Female     NaN
# 92157      Rank   31   31st    October  2019      Female   106.0
# 92158      Rank   31   31st   November  2019      Female     NaN
# 92159      Rank   31   31st   December  2019      Female    32.0
#
# [92160 rows x 7 columns]

# %% [markdown]
# From this point you can analyise the data - concatenating the data for the dates and creating an overall variable - you can also compare years and their birth rates.
#
# I do not think this dataset has the required 4 distinct variables so I have not choosen this for review.
#
# ****

# %% [markdown]
# ****
#
# <br>
#
# ### Selected Dataset - VSA36
#
# After reviewing datasets, including the datasets listed and overviews given above, I have decided to review the following:
#
# > https://data.cso.ie/table/VSA36
#
# <br>
#
# Please note that I have included copies of the dataset excel in the repository data file.
#
# However I have amended the headings and saved a file [here](Data/Births_VSA36.USE.csv), which I will use for analysis
#
# <br>
#
# This is a dataset that includes:
#
# Births
#
#       - Total
#       - Amount outside of marriage
#
# Year
#
#       - 2008 - 2020
#
# Age of Mother
#
#       - < 15
#       - > 45
#       - totals
#
# Previous Children
#
#       - 0-10
#       - not stated
#
# Value
#
#       - Number of Other Children

# %%
df = pd.read_csv('Data/Births_VSA36.USE.csv')   # read in the file

# %%
df                                              # print dataframe
# Out:
#       STATISTIC                                  Statistic  Year Age_Code  \
# 0      VSA36C01                               Total Births  2008       16
# 1      VSA36C01                               Total Births  2008       16
# 2      VSA36C01                               Total Births  2008       16
# 3      VSA36C01                               Total Births  2008       16
# 4      VSA36C01                               Total Births  2008       16
# ...         ...                                        ...   ...      ...
# 13177  VSA36C02  Births Outside Marriage/Civil Partnership  2020        -
# 13178  VSA36C02  Births Outside Marriage/Civil Partnership  2020        -
# 13179  VSA36C02  Births Outside Marriage/Civil Partnership  2020        -
# 13180  VSA36C02  Births Outside Marriage/Civil Partnership  2020        -
# 13181  VSA36C02  Births Outside Marriage/Civil Partnership  2020        -
#
#       Age_of_Mother  PLC_Code Previous_Liveborn_Children    UNIT  VALUE
# 0          16 years        26        Total Per Age Group  Number  170.0
# 1          16 years         1                          0  Number  160.0
# 2          16 years         2                          1  Number    9.0
# 3          16 years         3                          2  Number    NaN
# 4          16 years         4                          3  Number    NaN
# ...             ...       ...                        ...     ...    ...
# 13177      All ages        10                          7  Number    NaN
# 13178      All ages        11                          8  Number    NaN
# 13179      All ages        12                          9  Number    NaN
# 13180      All ages        15                 10 or more  Number    NaN
# 13181      All ages        99                 Not stated  Number    NaN
#
# [13182 rows x 9 columns]

# %%
df.info()                                      # dataframe info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13182 entries, 0 to 13181
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   STATISTIC                   13182 non-null  object
#  1   Statistic                   13182 non-null  object
#  2   Year                        13182 non-null  int64
#  3   Age_Code                    13182 non-null  object
#  4   Age_of_Mother               13182 non-null  object
#  5   PLC_Code                    13182 non-null  int64
#  6   Previous_Liveborn_Children  13182 non-null  object
#  7   UNIT                        13182 non-null  object
#  8   VALUE                       9006 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 927.0+ KB

# %% [markdown]
# ***
#
# ## Investigating the Dataset
#
# > https://data.cso.ie/table/VSA36
#
# [1]

# %%
# import libraries

import numpy as np                            # Mathimatical Python
import matplotlib.pyplot as plt               # Plotting Library
import seaborn as sns                         # Plotting library which works on top of Matplotlib

#[2][3][4]

# %%
df.info()                                     # dataframe info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13182 entries, 0 to 13181
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   STATISTIC                   13182 non-null  object
#  1   Statistic                   13182 non-null  object
#  2   Year                        13182 non-null  int64
#  3   Age_Code                    13182 non-null  object
#  4   Age_of_Mother               13182 non-null  object
#  5   PLC_Code                    13182 non-null  int64
#  6   Previous_Liveborn_Children  13182 non-null  object
#  7   UNIT                        13182 non-null  object
#  8   VALUE                       9006 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 927.0+ KB

# %%
df['VALUE'] = df['VALUE'].fillna(0)           # for the value column replace NAN with 0

# [5]

# %%
# Change data types

df['Age_Code'] = pd.to_numeric(df['Age_Code'], errors='coerce')   # change Age_Code - to a numeric output

# [6]

# %% [markdown]
# ***
#
# Total Births
#
# For this analysis we will review only the total births by year

# %%
df.iloc[6590]                                    # this is the last data point under Total Births
# Out:
# STATISTIC                         VSA36C01
# Statistic                     Total Births
# Year                                  2020
# Age_Code                               NaN
# Age_of_Mother                     All ages
# PLC_Code                                99
# Previous_Liveborn_Children      Not stated
# UNIT                                Number
# VALUE                                  0.0
# Name: 6590, dtype: object

# %%
df.loc[0:6590, :]                                # df cut down to only total births

# [7]
# Out:
#      STATISTIC     Statistic  Year  Age_Code Age_of_Mother  PLC_Code  \
# 0     VSA36C01  Total Births  2008      16.0      16 years        26
# 1     VSA36C01  Total Births  2008      16.0      16 years         1
# 2     VSA36C01  Total Births  2008      16.0      16 years         2
# 3     VSA36C01  Total Births  2008      16.0      16 years         3
# 4     VSA36C01  Total Births  2008      16.0      16 years         4
# ...        ...           ...   ...       ...           ...       ...
# 6586  VSA36C01  Total Births  2020       NaN      All ages        10
# 6587  VSA36C01  Total Births  2020       NaN      All ages        11
# 6588  VSA36C01  Total Births  2020       NaN      All ages        12
# 6589  VSA36C01  Total Births  2020       NaN      All ages        15
# 6590  VSA36C01  Total Births  2020       NaN      All ages        99
#
#      Previous_Liveborn_Children    UNIT  VALUE
# 0           Total Per Age Group  Number  170.0
# 1                             0  Number  160.0
# 2                             1  Number    9.0
# 3                             2  Number    0.0
# 4                             3  Number    0.0
# ...                         ...     ...    ...
# 6586                          7  Number   83.0
# 6587                          8  Number   46.0
# 6588                          9  Number   19.0
# 6589                 10 or more  Number   25.0
# 6590                 Not stated  Number    0.0
#
# [6591 rows x 9 columns]

# %%
df = df.loc[0:6590, :]                          # We now have a dataframe of total births only #[2]

# %%
df                                              # print df
# Out:
#      STATISTIC     Statistic  Year  Age_Code Age_of_Mother  PLC_Code  \
# 0     VSA36C01  Total Births  2008      16.0      16 years        26
# 1     VSA36C01  Total Births  2008      16.0      16 years         1
# 2     VSA36C01  Total Births  2008      16.0      16 years         2
# 3     VSA36C01  Total Births  2008      16.0      16 years         3
# 4     VSA36C01  Total Births  2008      16.0      16 years         4
# ...        ...           ...   ...       ...           ...       ...
# 6586  VSA36C01  Total Births  2020       NaN      All ages        10
# 6587  VSA36C01  Total Births  2020       NaN      All ages        11
# 6588  VSA36C01  Total Births  2020       NaN      All ages        12
# 6589  VSA36C01  Total Births  2020       NaN      All ages        15
# 6590  VSA36C01  Total Births  2020       NaN      All ages        99
#
#      Previous_Liveborn_Children    UNIT  VALUE
# 0           Total Per Age Group  Number  170.0
# 1                             0  Number  160.0
# 2                             1  Number    9.0
# 3                             2  Number    0.0
# 4                             3  Number    0.0
# ...                         ...     ...    ...
# 6586                          7  Number   83.0
# 6587                          8  Number   46.0
# 6588                          9  Number   19.0
# 6589                 10 or more  Number   25.0
# 6590                 Not stated  Number    0.0
#
# [6591 rows x 9 columns]

# %%
df.info()                                       # df info

# here we are looking the Dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6591 entries, 0 to 6590
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   STATISTIC                   6591 non-null   object
#  1   Statistic                   6591 non-null   object
#  2   Year                        6591 non-null   int64
#  3   Age_Code                    6422 non-null   float64
#  4   Age_of_Mother               6591 non-null   object
#  5   PLC_Code                    6591 non-null   int64
#  6   Previous_Liveborn_Children  6591 non-null   object
#  7   UNIT                        6591 non-null   object
#  8   VALUE                       6591 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 463.6+ KB

# %%
# complete a histogram of the birth numbers of 20 year olds across all years

total_birth_20 = df[(df.Age_Code==20) & (df.Previous_Liveborn_Children=="Total Per Age Group")] # filter df

total_birth_20 = total_birth_20 [["Year","VALUE"]]                                              # set df - columns

total_birth_20                                                                                  # print df

# [8][9][10][11]
# Out:
#       Year   VALUE
# 52    2008  1357.0
# 559   2009  1273.0
# 1066  2010  1175.0
# 1573  2011  1099.0
# 2080  2012   968.0
# 2587  2013   880.0
# 3094  2014   834.0
# 3601  2015   778.0
# 4108  2016   669.0
# 4615  2017   714.0
# 5122  2018   688.0
# 5629  2019   643.0
# 6136  2020   553.0

# %%
sns.histplot(data=total_birth_20, x='Year')               # plot histogram - x = Year

# [11][12][13]
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %% [markdown]
# Looking that the above histogram we can see that there seemed to be a large number of babies born to mothers aged 20 in 2008 - again in 2014 and again in 2020.
#
# This is a very low level look and we would need to take a larger slice of data to show more information on this dataset.

# %%
# create groups to plot

Year_08 = df[(df.Year == 2008) & (df['Age_Code'] > 290) & (df['Age_Code'] < 999)]   # Filter for 2008 - age code over than 290

#[14]

# %%
Year_08                                                  # print df
# Out:
#     STATISTIC     Statistic  Year  Age_Code      Age_of_Mother  PLC_Code  \
# 390  VSA36C01  Total Births  2008     355.0     Under 20 years        26
# 391  VSA36C01  Total Births  2008     355.0     Under 20 years         1
# 392  VSA36C01  Total Births  2008     355.0     Under 20 years         2
# 393  VSA36C01  Total Births  2008     355.0     Under 20 years         3
# 394  VSA36C01  Total Births  2008     355.0     Under 20 years         4
# ..        ...           ...   ...       ...                ...       ...
# 476  VSA36C01  Total Births  2008     510.0  45 years and over        10
# 477  VSA36C01  Total Births  2008     510.0  45 years and over        11
# 478  VSA36C01  Total Births  2008     510.0  45 years and over        12
# 479  VSA36C01  Total Births  2008     510.0  45 years and over        15
# 480  VSA36C01  Total Births  2008     510.0  45 years and over        99
#
#     Previous_Liveborn_Children    UNIT   VALUE
# 390        Total Per Age Group  Number  2402.0
# 391                          0  Number  2165.0
# 392                          1  Number   212.0
# 393                          2  Number    14.0
# 394                          3  Number     3.0
# ..                         ...     ...     ...
# 476                          7  Number     3.0
# 477                          8  Number     2.0
# 478                          9  Number     0.0
# 479                 10 or more  Number     1.0
# 480                 Not stated  Number     1.0
#
# [91 rows x 9 columns]

# %%
filter_list = ['Total Per Age Group']    # set filter variable


Year_08 = Year_08[Year_08.Previous_Liveborn_Children.isin(filter_list)]  # filter the data and set it as Year_08

Year_08                                  # print variable
# Out:
#     STATISTIC     Statistic  Year  Age_Code      Age_of_Mother  PLC_Code  \
# 390  VSA36C01  Total Births  2008     355.0     Under 20 years        26
# 403  VSA36C01  Total Births  2008     365.0      20 - 24 years        26
# 416  VSA36C01  Total Births  2008     410.0      25 - 29 years        26
# 429  VSA36C01  Total Births  2008     440.0      30 - 34 years        26
# 442  VSA36C01  Total Births  2008     460.0      35 - 39 years        26
# 455  VSA36C01  Total Births  2008     475.0      40 - 44 years        26
# 468  VSA36C01  Total Births  2008     510.0  45 years and over        26
#
#     Previous_Liveborn_Children    UNIT    VALUE
# 390        Total Per Age Group  Number   2402.0
# 403        Total Per Age Group  Number   9283.0
# 416        Total Per Age Group  Number  17876.0
# 429        Total Per Age Group  Number  25431.0
# 442        Total Per Age Group  Number  16913.0
# 455        Total Per Age Group  Number   3077.0
# 468        Total Per Age Group  Number    166.0

# %%
# plot 2008 data

plt.figure(figsize = (15,8))                                     # set plot size

ax = sns.lineplot(data=Year_08, x="Age_of_Mother", y="VALUE")    # set lineplot, data and points

plt.xticks(rotation=45)                                          # set the x tick labels at a rotation

# [15][16]
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
Year_All = df[(df.Year >= 2008) & (df['Age_Code'] > 290) & (df['Age_Code'] < 999)]  # set data for all years


filter_list = ['Total Per Age Group']                                               # filter this data to total per age group
Year_All = Year_All[Year_All.Previous_Liveborn_Children.isin(filter_list)]          # set filtered variable
Year_All                                                                            # print variable
# Out:
#      STATISTIC     Statistic  Year  Age_Code      Age_of_Mother  PLC_Code  \
# 390   VSA36C01  Total Births  2008     355.0     Under 20 years        26
# 403   VSA36C01  Total Births  2008     365.0      20 - 24 years        26
# 416   VSA36C01  Total Births  2008     410.0      25 - 29 years        26
# 429   VSA36C01  Total Births  2008     440.0      30 - 34 years        26
# 442   VSA36C01  Total Births  2008     460.0      35 - 39 years        26
# ...        ...           ...   ...       ...                ...       ...
# 6500  VSA36C01  Total Births  2020     410.0      25 - 29 years        26
# 6513  VSA36C01  Total Births  2020     440.0      30 - 34 years        26
# 6526  VSA36C01  Total Births  2020     460.0      35 - 39 years        26
# 6539  VSA36C01  Total Births  2020     475.0      40 - 44 years        26
# 6552  VSA36C01  Total Births  2020     510.0  45 years and over        26
#
#      Previous_Liveborn_Children    UNIT    VALUE
# 390         Total Per Age Group  Number   2402.0
# 403         Total Per Age Group  Number   9283.0
# 416         Total Per Age Group  Number  17876.0
# 429         Total Per Age Group  Number  25431.0
# 442         Total Per Age Group  Number  16913.0
# ...                         ...     ...      ...
# 6500        Total Per Age Group  Number   9396.0
# 6513        Total Per Age Group  Number  19239.0
# 6526        Total Per Age Group  Number  17583.0
# 6539        Total Per Age Group  Number   4347.0
# 6552        Total Per Age Group  Number    354.0
#
# [91 rows x 9 columns]

# %%
Year_All_1 = Year_All[["Year", "Age_of_Mother", "VALUE"]]  # take subset of the variable

# %%
Year_All_1                                                 # print subset
# Out:
#       Year      Age_of_Mother    VALUE
# 390   2008     Under 20 years   2402.0
# 403   2008      20 - 24 years   9283.0
# 416   2008      25 - 29 years  17876.0
# 429   2008      30 - 34 years  25431.0
# 442   2008      35 - 39 years  16913.0
# ...    ...                ...      ...
# 6500  2020      25 - 29 years   9396.0
# 6513  2020      30 - 34 years  19239.0
# 6526  2020      35 - 39 years  17583.0
# 6539  2020      40 - 44 years   4347.0
# 6552  2020  45 years and over    354.0
#
# [91 rows x 3 columns]

# %%
plt.figure(figsize = (15,8))                                        # plot size set

ax = sns.lineplot(data=Year_All_1, x="Age_of_Mother", y="VALUE")    # lineplot - Age of mother by number of children

plt.xticks(rotation=45)                                             # rotate x ticks
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize = (15,8))                                                     # plot size set 

ax = sns.lineplot(data=Year_All_1, x="Age_of_Mother", y="VALUE", hue="Year")     # lineplot - Age of mother by number of children

plt.xticks(rotation=45)                                                          # rotate x ticks 

# in this graph we have added a hue by year which breaks out the line graph - showing each year
# this is dfferent from the above as it breaks out the hue


# [17]
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ****
#
# From the above graph we can see that over all the years, in all demographic groups, the age at which woman had the most children was 30 - 34.
#
# We can also see that the number of children born to women before the this age segment has also decreased steadly from 2008 - 2020.
#
#
# Further the number of children born has also decreased but we would need further investigation to expand on this point.
#
#
# ****
#
#
# <br>
#
# List potential other plots
#
#
# ***

# %%
df_M = pd.read_csv('Data/Births_VSA36.USE.csv')

# %%
df_M['VALUE'] = df_M['VALUE'].fillna(0) 
df_M['Age_Code'] = pd.to_numeric(df_M['Age_Code'], errors='coerce')

# %%
df_M
# Out:
#       STATISTIC                                  Statistic  Year  Age_Code  \
# 0      VSA36C01                               Total Births  2008      16.0
# 1      VSA36C01                               Total Births  2008      16.0
# 2      VSA36C01                               Total Births  2008      16.0
# 3      VSA36C01                               Total Births  2008      16.0
# 4      VSA36C01                               Total Births  2008      16.0
# ...         ...                                        ...   ...       ...
# 13177  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13178  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13179  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13180  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13181  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
#
#       Age_of_Mother  PLC_Code Previous_Liveborn_Children    UNIT  VALUE
# 0          16 years        26        Total Per Age Group  Number  170.0
# 1          16 years         1                          0  Number  160.0
# 2          16 years         2                          1  Number    9.0
# 3          16 years         3                          2  Number    0.0
# 4          16 years         4                          3  Number    0.0
# ...             ...       ...                        ...     ...    ...
# 13177      All ages        10                          7  Number    0.0
# 13178      All ages        11                          8  Number    0.0
# 13179      All ages        12                          9  Number    0.0
# 13180      All ages        15                 10 or more  Number    0.0
# 13181      All ages        99                 Not stated  Number    0.0
#
# [13182 rows x 9 columns]

# %%
df_M = df_M.loc[6591:]

# %%
df_M
# Out:
#       STATISTIC                                  Statistic  Year  Age_Code  \
# 6591   VSA36C02  Births Outside Marriage/Civil Partnership  2008      16.0
# 6592   VSA36C02  Births Outside Marriage/Civil Partnership  2008      16.0
# 6593   VSA36C02  Births Outside Marriage/Civil Partnership  2008      16.0
# 6594   VSA36C02  Births Outside Marriage/Civil Partnership  2008      16.0
# 6595   VSA36C02  Births Outside Marriage/Civil Partnership  2008      16.0
# ...         ...                                        ...   ...       ...
# 13177  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13178  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13179  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13180  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
# 13181  VSA36C02  Births Outside Marriage/Civil Partnership  2020       NaN
#
#       Age_of_Mother  PLC_Code Previous_Liveborn_Children    UNIT  VALUE
# 6591       16 years        26        Total Per Age Group  Number  168.0
# 6592       16 years         1                          0  Number  158.0
# 6593       16 years         2                          1  Number    9.0
# 6594       16 years         3                          2  Number    0.0
# 6595       16 years         4                          3  Number    0.0
# ...             ...       ...                        ...     ...    ...
# 13177      All ages        10                          7  Number    0.0
# 13178      All ages        11                          8  Number    0.0
# 13179      All ages        12                          9  Number    0.0
# 13180      All ages        15                 10 or more  Number    0.0
# 13181      All ages        99                 Not stated  Number    0.0
#
# [6591 rows x 9 columns]

# %%
Married_All = df_M[(df_M.Year >= 2008) & (df_M['Age_Code'] > 290) & (df_M['Age_Code'] < 999)]


filter_list = ['Total Per Age Group']
Married_All = Married_All[Married_All.Previous_Liveborn_Children.isin(filter_list)]
Married_All
# Out:
#       STATISTIC                                  Statistic  Year  Age_Code  \
# 6981   VSA36C02  Births Outside Marriage/Civil Partnership  2008     355.0
# 6994   VSA36C02  Births Outside Marriage/Civil Partnership  2008     365.0
# 7007   VSA36C02  Births Outside Marriage/Civil Partnership  2008     410.0
# 7020   VSA36C02  Births Outside Marriage/Civil Partnership  2008     440.0
# 7033   VSA36C02  Births Outside Marriage/Civil Partnership  2008     460.0
# ...         ...                                        ...   ...       ...
# 13091  VSA36C02  Births Outside Marriage/Civil Partnership  2020     410.0
# 13104  VSA36C02  Births Outside Marriage/Civil Partnership  2020     440.0
# 13117  VSA36C02  Births Outside Marriage/Civil Partnership  2020     460.0
# 13130  VSA36C02  Births Outside Marriage/Civil Partnership  2020     475.0
# 13143  VSA36C02  Births Outside Marriage/Civil Partnership  2020     510.0
#
#            Age_of_Mother  PLC_Code Previous_Liveborn_Children    UNIT   VALUE
# 6981      Under 20 years        26        Total Per Age Group  Number  2220.0
# 6994       20 - 24 years        26        Total Per Age Group  Number  7109.0
# 7007       25 - 29 years        26        Total Per Age Group  Number  7663.0
# 7020       30 - 34 years        26        Total Per Age Group  Number  4870.0
# 7033       35 - 39 years        26        Total Per Age Group  Number  2610.0
# ...                  ...       ...                        ...     ...     ...
# 13091      25 - 29 years        26        Total Per Age Group  Number     0.0
# 13104      30 - 34 years        26        Total Per Age Group  Number     0.0
# 13117      35 - 39 years        26        Total Per Age Group  Number     0.0
# 13130      40 - 44 years        26        Total Per Age Group  Number     0.0
# 13143  45 years and over        26        Total Per Age Group  Number     0.0
#
# [91 rows x 9 columns]

# %%
Married_All = Married_All[["Year", "Age_of_Mother", "VALUE"]]
Married_All
# Out:
#        Year      Age_of_Mother   VALUE
# 6981   2008     Under 20 years  2220.0
# 6994   2008      20 - 24 years  7109.0
# 7007   2008      25 - 29 years  7663.0
# 7020   2008      30 - 34 years  4870.0
# 7033   2008      35 - 39 years  2610.0
# ...     ...                ...     ...
# 13091  2020      25 - 29 years     0.0
# 13104  2020      30 - 34 years     0.0
# 13117  2020      35 - 39 years     0.0
# 13130  2020      40 - 44 years     0.0
# 13143  2020  45 years and over     0.0
#
# [91 rows x 3 columns]

# %%
plt.figure(figsize = (15,8))                                                     # plot size set 

ax = sns.lineplot(data=Married_All, x="Age_of_Mother", y="VALUE", hue="Year")     # lineplot - Age of mother by number of children

plt.xticks(rotation=45)                                                          # rotate x ticks
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize = (15,8))                                        # plot size set

ax = sns.lineplot(data=Year_All_1, x="Age_of_Mother", y="VALUE")    # lineplot - Age of mother by number of children
ax1 = sns.lineplot(data=Married_All, x="Age_of_Mother", y="VALUE") 

plt.xticks(rotation=45)                                             # rotate x ticks 
plt.legend(labels=["Total Births","Births Outside Marriage"], title = "Title_Legend")
